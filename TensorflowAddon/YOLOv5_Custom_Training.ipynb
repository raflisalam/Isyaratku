# %% [markdown]
# # Step 1: Install Requirements

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls ../drive/MyDrive/
# Out:
#  1669002893142.jpeg
#  1669003028406.jpeg
#  1669202440725.jpeg
# 'Apa Itu Software Development Life Cycle (SDLC).gdoc'
#  APKTedi
#  Bangkit
# 'Big Data Algoritm PowerPoint Templates (1).pptx'
# 'Dokumen MAP lokasi booth CDC.gdoc'
# 'Dokumen Pengerjaan Lomba'
# 'Dokumen Req Lomba'
#  Excel
#  FinRafli
#  gemastik.pdf
#  i01_whatsapp-image-2022-10-24-at-12.36.05.jpeg
#  image_2022-12-13_201026630.png
# 'Machine Learning'
# 'Presentasi tanpa judul.gslides'
#  PrintKambing
#  SDLC_FernandoArgaWijaya.pptx
#  TA_PratamaAzmiAtmajaya
#  TeDi
#  TeDi_Documentation
# 'TPA Kambing'
# 'WhatsApp Image 2022-10-24 at 09.33.00.jpeg'
# 'WhatsApp Image 2022-10-24 at 12.36.05.jpeg'

# %%
# !unzip ../drive/MyDrive/FinRafli/placeFolder.zip -d ./data
# Out:
# Archive:  ../drive/MyDrive/FinRafli/placeFolder.zip
#    creating: ./data/placeFolder/images/
#    creating: ./data/placeFolder/images/train/
#   inflating: ./data/placeFolder/images/train/besok.98c8c8a3-81a4-11ed-8b0e-c03fd5a31d89.jpg
#   inflating: ./data/placeFolder/images/train/besok.a895182c-81a4-11ed-a4a0-c03fd5a31d89.jpg
#   inflating: ./data/placeFolder/images/train/besok.c358aaae-81a4-11ed-9558-c03fd5a31d89.jpg
#   inflating: ./data/placeFolder/images/train/besok.c9704506-81a4-11ed-b723-c03fd5a31d89.jpg
#   inflating: ./data/placeFolder/images/train/dia.03bcc09f-8196-11ed-bde6-c03fd5a31d89.jpg
#   inflating: ./data/placeFolder/images/train/dia.0c3d0c56-8196-11ed-8478-c03fd5a31d89.jpg
#   inflating: ./data/placeFolder/images/train/dia.15ec12f4-8196-11ed-b064-c03fd5a31d89.jpg
#   inflating: ./data/placeFolder/images/train/dia.26e33edd-8196-11ed-b071-c03fd5a31d89.jpg
#   inflating: ./data/placeFolder/images/train/guru.c3eacf33-8570-11ed-899c-c03fd5a31d89.jpg
# ...

# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14936, done.
# remote: Total 14936 (delta 0), reused 0 (delta 0), pack-reused 14936
# Receiving objects: 100% (14936/14936), 13.99 MiB | 28.20 MiB/s, done.
# Resolving deltas: 100% (10259/10259), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 44.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 KB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 6.9 MB/s eta 0:00:00
# ...
# Setup complete. Using torch 1.13.0+cu116 (Tesla T4)

# %% [markdown]
# # Step 2: Assemble Our Dataset
#
# In order to train our custom model, we need to assemble a dataset of representative images with bounding box annotations around the objects that we want to detect. And we need our dataset to be in YOLOv5 format.
#
# In Roboflow, you can choose between two paths:
#
# * Convert an existing dataset to YOLOv5 format. Roboflow supports over [30 formats object detection formats](https://roboflow.com/formats) for conversion.
# * Upload raw images and annotate them in Roboflow with [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# # Annotate
#
# ![](https://roboflow-darknet.s3.us-east-2.amazonaws.com/roboflow-annotate.gif)
#
# # Version
#
# ![](https://roboflow-darknet.s3.us-east-2.amazonaws.com/robolfow-preprocessing.png)

# %%
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
#after following the link above, recieve python code with these fields filled in
#from roboflow import Roboflow
#rf = Roboflow(api_key="YOUR API KEY HERE")
#project = rf.workspace().project("YOUR PROJECT")
#dataset = project.version("YOUR VERSION").download("yolov5")
# Out:
# ...
# Extracting Dataset Version Zip to /content/datasets/American-Mushrooms-1 in yolov5pytorch:: 100%|██████████| 278/278 [00:00<00:00, 1046.33it/s]

# %% [markdown]
# # Step 3: Train Our Custom YOLOv5 model
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** Our dataset locaiton is saved in the `dataset.location`
# - **weights:** specify a path to weights to start transfer learning from. Here we choose the generic COCO pretrained checkpoint.
# - **cache:** cache images for faster training

# %%
# Out:
# benchmarks.py    data/       LICENSE          requirements.txt  tutorial.ipynb
# CITATION.cff     detect.py   models/          segment/          utils/
# classify/        export.py   README.md        setup.cfg         val.py
# CONTRIBUTING.md  hubconf.py  README.zh-CN.md  train.py

# %%
# !python train.py --img 320 --batch 16 --epochs 10 --data sibi.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=sibi.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-59-gfdc35b1 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python export.py --weights runs/train/exp6/weights/best.pt --data data/sibi.yaml --include tflite --img 320
# Out:
# export: data=data/sibi.yaml, weights=['runs/train/exp6/weights/best.pt'], imgsz=[320], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-59-gfdc35b1 Python-3.8.16 torch-1.13.0+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7077550 parameters, 0 gradients, 16.0 GFLOPs
#
# PyTorch: starting from runs/train/exp6/weights/best.pt with output shape (1, 6300, 30) (13.7 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.9.2...
#
#                  from  n    params  module                                  arguments
# 2023-01-09 10:56:50.328031: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# !zip -r runs.zip runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/train/ (stored 0%)
#   adding: runs/train/exp6/ (stored 0%)
#   adding: runs/train/exp6/val_batch1_pred.jpg (deflated 20%)
#   adding: runs/train/exp6/val_batch2_labels.jpg (deflated 21%)
#   adding: runs/train/exp6/val_batch2_pred.jpg (deflated 26%)
#   adding: runs/train/exp6/weights/ (stored 0%)
#   adding: runs/train/exp6/weights/best-fp16.tflite (deflated 8%)
#   adding: runs/train/exp6/weights/best.pt (deflated 8%)
#   adding: runs/train/exp6/weights/last.pt (deflated 8%)
#   adding: runs/train/exp6/weights/best_saved_model/ (stored 0%)
#   adding: runs/train/exp6/weights/best_saved_model/assets/ (stored 0%)
#   adding: runs/train/exp6/weights/best_saved_model/saved_model.pb (deflated 8%)
#   adding: runs/train/exp6/weights/best_saved_model/variables/ (stored 0%)
#   adding: runs/train/exp6/weights/best_saved_model/variables/variables.index (deflated 33%)
# ...
